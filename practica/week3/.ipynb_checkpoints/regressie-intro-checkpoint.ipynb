# %% [markdown]
# # Regressie - intro

# %% [markdown]
# ![nerd.jpg](attachment:nerd.jpg)

# %% [markdown]
# ## Install

# %%
# !pip3 install numpy
# !pip3 install scipy
# Out:
# Requirement already satisfied: numpy in /Users/danielschene/miniconda3/envs/miw/lib/python3.10/site-packages (1.24.2)
# Requirement already satisfied: scipy in /Users/danielschene/miniconda3/envs/miw/lib/python3.10/site-packages (1.10.0)
# Requirement already satisfied: numpy<1.27.0,>=1.19.5 in /Users/danielschene/miniconda3/envs/miw/lib/python3.10/site-packages (from scipy) (1.24.2)

# %% [markdown]
# ## Import

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy as cp
np.random.seed(42)

# %% [markdown]
# ## Predefine

# %%
def plot_init():
    
    fig, ax = plt.subplots()
    
    return ax


def plot_add(ax, x, y):
    
    ax.plot(x, y, linewidth=2.0)


def plot_show():
    
    plt.show()


def plot_graph(x, y):
    
    ax = plot_init()
    plot_add(ax, x, y)
    plot_show()

# %% [markdown]
# ## Lineair verband
# ### Model
# huizenprijs = vastgoed offset + prijs per oppervlak x oppervlak
#
# p = 25.000 + 5.000 x oppervlak

# %% [markdown]
# ### Stap 1: Maak huizenprijs model

# %%
# create a function which outputs the house price for a given surface value

def get_price(m_2, offset_price = 25000, opp_price = 5000):
    return offset_price + (opp_price * m_2)

# %% [markdown]
# ### Stap 2: Bekijk interval [50, 75] m2

# %%
#we can create an array of the surface values in the 50-250 range
np_surfaces = np.arange(50, 250)

#we then create an array of the house prices for the range of surface values
np_prices = np.array([get_price(n) for n in range(50,250)])


#adding noise to the np_prices array, and overwriting it. In this case the noise ranges between 0 and 25000
np_prices = np.random.normal(np_prices, 50_000)

#we can plot the values with the surface on the x-axis and the prices on the y-axis
plot_graph(np_surfaces, np_prices)

# %%
#we can take the 50-75 m2 range by slicing the data
m2_50_75 = np_surfaces[0:25]
array_50_75 = np_prices[0:25]
print(array_50_75)

plot_graph(m2_50_75, array_50_75)
# Out:
# [323912.62092015 391861.25372177 363238.03367627 269806.33003143
#  338428.14203455 316970.33399656 272027.44501465 331364.65574766
#  291309.50488671 326217.68245857 256080.11445411 241853.45065473
#  320673.15536021 355907.07809859 288606.81592148 376314.76271933
#  357137.47562653 392512.58440916 412281.92776795 437178.83214796
#  405163.60304353 365236.78295271 394443.13770461 506459.04655858
#  444273.23559161]

# %% [markdown]
# ### Stap 3: Fit data
#
# #### Use the curve fitting
#
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.curve_fit.html

# %%
#The final step is optimizing the fit of the model, which will return two values:
    #an optimal 'a' and an optimal 'b' value which we can plug into our model
    
#print(cp.optimize.curve_fit(get_price, np_surfaces, np_prices))


def func(x, a, b):
    return a + b * x

house_prices_fit, _ = cp.optimize.curve_fit(func, m2_50_75, array_50_75)

print(house_prices_fit)


house_prices_prediction = house_prices_fit[0] + house_prices_fit[1] * m2_50_75


ax = plot_init()

plot_add(ax, m2_50_75, array_50_75)

plot_add(ax, m2_50_75, house_prices_prediction)


# Create fit
# Out:
# [17746.33537744  5377.80620714]

# %% [markdown]
# ### Stap 4: Extrapoleer

# %%
#now we can extrapolate using the optimized fit values for a and b, namely:

def optimized_price(x, a = house_prices_fit[1], b = house_prices_fit[0]):
    return a * x + b

#we can now compare the two fits
print(optimized_price(100))
print(get_price(100))



#we can compare the two lines by plotting them
a_x = plot_init()

#we'll do this for the whole range of prices from 50 m2 to 250 m2

first_model = np.array([get_price(n) for n in all_surfaces_array])
second_model = np.array([optimized_price(n) for n in np_surfaces])

plot_add(a_x, np_surfaces, np_prices)
plot_add(a_x, np_surfaces, second_model)
# Out:
# 555526.9560912083
# 525000

# %% [markdown]
# ## Polynomiale verbanden

# %% [markdown]
# ### Model
#
# ![bol-mannetje.jpg](attachment:bol-mannetje.jpg)
#
# massa bolmannetje = dichtheid x bolvormigheid + benen + armen + hoofd
#
# mass_bolman = 1.03 x radius^3 + 12.4 + 8.7 + 3.2

# %% [markdown]
# ### Stap 1: Maak model bolmannetje

# %%
#we first create a function calculating the mass:

def get_mass(r, density = 1.03, legs = 12.4, arms = 8.7, head = 3.2):
    return density*(r**3) + legs + arms + head

# %% [markdown]
# ### Stap 2: Fit data

# %%
# Define our model

x_array = np.arange(1,10,0.1)
mass_array = np.array([get_mass(n) for n in x_array])

#add_noise

mass_array = np.random.normal(mass_array, 20.3)

plot_graph(x_array, mass_array)


# Use scipy optimize package

#def get_mass_2(x, a, b):

def get_mass_2(x, a, b):
    
    return a + np.array(b * x**3)

# Create fit
fit, var= cp.optimize.curve_fit(get_mass_2, x_array, mass_array)

print(fit)
# Plot fit

# ...
# Out:
# [25.74984457  1.02002429]

# %%
def optimized_mass(r, density = fit[0], legs = fit[1], arms = fit[2], head = fit['head']):
    return

# %% [markdown]
# ## Combinatie periodiek en exponentieel verband

# %% [markdown]
# ### Model
#
# Finding Seasonal Trends in Time-Series Data
#
# https://towardsdatascience.com/finding-seasonal-trends-in-time-series-data-with-python-ce10c37aa861
