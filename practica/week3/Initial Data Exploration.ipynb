# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# '/Users/danielschene/MakeAIWork/practica/week3'

# %%
df = pd.read_csv('energie_afhankelijkheid.csv', sep=';', encoding='latin1')

# %%
display(df)
# Out:
#             country         2010        2011         2012         2013  \
# 0   C.A. de Euskadi  94,25488685  94,1780926  94,50532908  93,99908887
# 1             UE 27       55,766      56,359       54,918       53,939
# 2          Alemania       59,992      61,801       61,215       62,411
# 3           Austria       62,779      69,976       63,782       61,261
# 4           Belgica       78,553      76,464       76,563       77,777
# 5          Bulgaria       40,146      36,732       36,859       38,313
# 6            Chipre      100,636      92,263       96,748       96,071
# 7           Croacia       46,693      49,639       49,862       47,434
# 8         Dinamarca      -16,235      -6,315       -3,176       12,312
# 9        Eslovaquia       64,448      65,933       61,625       60,825
# 10        Eslovenia       49,277      48,329       51,813       47,461
# 11           España       77,003      76,012       72,798       69,997
# ...
